# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt

# %%
data = pd.read_csv("bigmartsales-cleaned.csv")

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 50) # None - show all the rows- will load into

# %%
data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# 3  Fruits and Vegetables     182.1            OUT010
# 4              Household      53.9            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 2
# 1                       2009      Medium               Tier 2
# ...

# %%
data.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods     214.5            OUT013
# 8519        Baking Goods     108.2            OUT045
# 8520  Health and Hygiene      85.1            OUT035
# 8521         Snack Foods     103.1            OUT018
# 8522         Soft Drinks      75.5            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN                  NaN
# ...

# %%
data.sample(5) # random numbers
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8292           FDF56         0.00          Regular         0.209163
# 6965           NCZ41        19.85          Low Fat         0.000000
# 3057           FDX25        16.70          Low Fat         0.102036
# 6134           FDF40          NaN          Regular         0.022403
# 8091           FDW08        12.10          Low Fat         0.148986
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8292  Fruits and Vegetables     179.2            OUT019
# 6965     Health and Hygiene     126.2            OUT018
# 3057                 Canned     180.9            OUT035
# 6134                  Dairy     250.9            OUT027
# 8091  Fruits and Vegetables     106.5            OUT018
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8292                       1985       Small                Tier1
# 6965                       2009      Medium               Tier 2
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7774 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       6473 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  Profit                     8523 non-null   float64
# ...

# %%
# Dtype - object/int/float
data.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7774.000000      8523.000000  8523.000000                8523.000000
# mean     11.676740         0.066132   140.998838                1997.831867
# std       5.776851         0.051598    62.258099                   8.371760
# min       0.000000         0.000000    31.300000                1985.000000
# 25%       7.720000         0.026989    93.800000                1987.000000
# 50%      11.800000         0.053931   142.700000                1999.000000
# 75%      16.500000         0.094585   185.650000                2004.000000
# max      21.350000         0.328391   266.900000                2009.000000
#
#        Item_Outlet_Sales       Profit
# count        8523.000000  8523.000000
# mean         2181.288914    13.414514
# std          1706.499616     1.701840
# min            33.290000     0.100000
# 25%           834.247400    13.150000
# 50%          1794.331000    13.900000
# ...

# %%
data[['Item_Identifier', 'Item_Weight', 'Item_Fat_Content']][0:3]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
# data[['Item_Identifier', 'Item_Weight', 'Item_Fat_Content']][0:3]

data.loc[[0, 1, 2], ['Item_Identifier', 'Item_Weight', 'Item_Fat_Content']] # name of rows and columns
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat

# %%
data.loc[0:2, 'Item_Identifier':'Item_Fat_Content'] # in loc it includes 0 and 2
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat

# %%
data.iloc[:3,:3] # it will ignore 3
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat

# %%
# Selecting 2 columns, below all are valid
data.Item_Identifier
data["Item_Identifier"]
data[["Item_Identifier"]]
# Out:
#      Item_Identifier
# 0              FDA15
# 1              DRC01
# 2              FDN15
# 3              FDX07
# 4              NCD19
# ...              ...
# 8518           FDF22
# 8519           FDS36
# 8520           NCJ29
# 8521           FDN46
# 8522           DRG01
#
# [8523 rows x 1 columns]

# %%
data.loc[0:4, ['Item_Identifier', 'Item_Weight', 'Item_Fat_Content']]
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat
# 3           FDX07        19.20          Regular
# 4           NCD19         8.93          Low Fat

# %%
data[['Item_Identifier', 'Item_Weight', 'Item_Fat_Content']].head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content
# 0           FDA15         9.30          Low Fat
# 1           DRC01         5.92          Regular
# 2           FDN15        17.50          Low Fat
# 3           FDX07        19.20          Regular
# 4           NCD19         8.93          Low Fat

# %%
data.loc[:,"Item_Identifier": "Item_Fat_Content"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content
# 0              FDA15        9.300          Low Fat
# 1              DRC01        5.920          Regular
# 2              FDN15       17.500          Low Fat
# 3              FDX07       19.200          Regular
# 4              NCD19        8.930          Low Fat
# ...              ...          ...              ...
# 8518           FDF22        6.865          Low Fat
# 8519           FDS36        8.380          Regular
# 8520           NCJ29       10.600          Low Fat
# 8521           FDN46        7.210          Regular
# 8522           DRG01       14.800          Low Fat
#
# [8523 rows x 3 columns]

# %%
data.iloc[:, ::-1] # column flipping
# Out:
#       Profit  Item_Outlet_Sales        Outlet_Type Outlet_Location_Type  \
# 0       11.5          3735.1380  Supermarket Type1               Tier 2
# 1       14.3           443.4228  Supermarket Type2               Tier 2
# 2       14.5          2097.2700  Supermarket Type1               Tier 2
# 3       13.6           732.3800      Grocery Store                  NaN
# 4       14.1           994.7052  Supermarket Type1               Tier 3
# ...      ...                ...                ...                  ...
# 8518    14.1          2778.3834  Supermarket Type1               Tier 3
# 8519    14.2           549.2850  Supermarket Type1                  NaN
# 8520     9.5          1193.1136  Supermarket Type1                Tier1
# 8521    14.2          1845.5976  Supermarket Type2               Tier 2
# 8522    14.6           765.6700  Supermarket Type1                Tier1
#
#      Outlet_Size  Outlet_Establishment_Year Outlet_Identifier  Item_MRP  \
# ...

# %%
data.iloc[::-1, ::-1] # column and row flipping
# Out:
#       Profit  Item_Outlet_Sales        Outlet_Type Outlet_Location_Type  \
# 8522    14.6           765.6700  Supermarket Type1                Tier1
# 8521    14.2          1845.5976  Supermarket Type2               Tier 2
# 8520     9.5          1193.1136  Supermarket Type1                Tier1
# 8519    14.2           549.2850  Supermarket Type1                  NaN
# 8518    14.1          2778.3834  Supermarket Type1               Tier 3
# ...      ...                ...                ...                  ...
# 4       14.1           994.7052  Supermarket Type1               Tier 3
# 3       13.6           732.3800      Grocery Store                  NaN
# 2       14.5          2097.2700  Supermarket Type1               Tier 2
# 1       14.3           443.4228  Supermarket Type2               Tier 2
# 0       11.5          3735.1380  Supermarket Type1               Tier 2
#
#      Outlet_Size  Outlet_Establishment_Year Outlet_Identifier  Item_MRP  \
# ...

# %%
data.T # Transpose or rotate diagonal
# Out:
#                                         0                  1     \
# Item_Identifier                        FDA15              DRC01
# Item_Weight                              9.3               5.92
# Item_Fat_Content                     Low Fat            Regular
# Item_Visibility                     0.016047           0.019278
# Item_Type                              Dairy        Soft Drinks
# Item_MRP                               249.8               48.3
# Outlet_Identifier                     OUT049             OUT018
# Outlet_Establishment_Year               1999               2009
# Outlet_Size                           Medium             Medium
# Outlet_Location_Type                  Tier 2             Tier 2
# Outlet_Type                Supermarket Type1  Supermarket Type2
# Item_Outlet_Sales                   3735.138           443.4228
# Profit                                  11.5               14.3
#
# ...

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
data[data["Outlet_Size"] == 'Small']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 11             FDA03        18.50          Regular         0.045464
# 13             FDS46        17.60          Regular         0.047257
# 15             FDP49         9.00          Regular         0.069089
# 19             FDU02        13.35          Low Fat         0.102492
# 22             NCB30        14.60          Low Fat         0.025698
# ...              ...          ...              ...              ...
# 8510           FDN58        13.80          Regular         0.056862
# 8513           FDH31        12.00          Regular         0.020407
# 8517           FDF53        20.75          Regular         0.083607
# 8520           NCJ29        10.60          Low Fat         0.035186
# 8522           DRG01        14.80          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 11                 Dairy     144.1            OUT046
# ...

# %%
data[(data["Outlet_Size"] == 'Small') & (data["Item_MRP"] <= 100)] # Both conditions satisfied
data[(data["Outlet_Size"] == 'Small') | (data["Item_MRP"] <= 100)] # at least one condition satisfied
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1              DRC01        5.920          Regular         0.019278
# 4              NCD19        8.930          Low Fat         0.000000
# 5              FDP36       10.395          Regular         0.000000
# 6              FDO10       13.650          Regular         0.012741
# 8              FDH17       16.200          Regular         0.016687
# ...              ...          ...              ...              ...
# 8514           FDA01       15.000          Regular         0.054489
# 8516           NCJ19       18.600          Low Fat         0.118661
# 8517           FDF53       20.750          Regular         0.083607
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 1            Soft Drinks      48.3            OUT018
# ...

# %%
# data.sort_values(by="Item_MRP", ascending=False)
data.sort_values("Item_MRP", ascending=True)
data.sort_values(["Item_MRP"], ascending=True)
data.sort_values(["Item_MRP", "Outlet_Establishment_Year"], ascending=[True, False])
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 153            DRK12          NaN          Low Fat         0.041683
# 6958           DRK12        9.500          Low Fat         0.041851
# 2135           DRK12        9.500          Low Fat         0.042057
# 2011           FDX59       10.195          Low Fat         0.051618
# 2242           FDG40          NaN          Low Fat         0.039631
# ...              ...          ...              ...              ...
# 4538           FDS13          NaN          Low Fat         0.217994
# 4159           FDK51       19.850          Low Fat         0.008763
# 5254           NCS29        9.000          Low Fat         0.069488
# 4802           FDS13        6.465          Low Fat         0.125210
# 5884           FDR25       17.000          Regular         0.139522
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 153          Soft Drinks      31.3            OUT027
# ...

# %%
data["Item_MRP"].round().astype("int64")
# Out:
# 0       250
# 1        48
# 2       142
# 3       182
# 4        54
#        ...
# 8518    214
# 8519    108
# 8520     85
# 8521    103
# 8522     76
# Name: Item_MRP, Length: 8523, dtype: int64

# %%
data["Item_MRP"]
# Out:
# 0       249.8
# 1        48.3
# 2       141.6
# 3       182.1
# 4        53.9
#         ...
# 8518    214.5
# 8519    108.2
# 8520     85.1
# 8521    103.1
# 8522     75.5
# Name: Item_MRP, Length: 8523, dtype: float64

# %%
def nearest_int(num):
  pre = int(num)
  next_n = pre + 1
  fractional_part = num - pre

  if fractional_part >= 0.5:
    return next_n
  else:
    return pre

# %%
nearest_int(50)
# Out:
# 50

# %%
data["Item_MRP"] = data["Item_MRP"].apply(nearest_int)

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy       250            OUT049
# ...

# %%
data["Outlet_Identifier"].apply(lambda x: x.replace("OUT", ""))
# Out:
# 0       049
# 1       018
# 2       049
# 3       010
# 4       013
#        ...
# 8518    013
# 8519    045
# 8520    035
# 8521    018
# 8522    046
# Name: Outlet_Identifier, Length: 8523, dtype: object

# %% [markdown]
# # Data Preprocessing

# %%
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy       250            OUT049
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7774 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   int64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       6473 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
#  12  Profit                     8523 non-null   float64
# ...

# %%
data_object = data.select_dtypes("object")
data_int = data.select_dtypes("int")
data_float = data.select_dtypes("float")

# %%
data_object
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 2  Supermarket Type1
# 1               OUT018      Medium               Tier 2  Supermarket Type2
# ...

# %%
data_float.isnull().sum()
# Out:
# Item_Weight          749
# Item_Visibility        0
# Item_Outlet_Sales      0
# Profit                 0
# dtype: int64

# %%
# Null values can be replace with mean/median

for col in data_float.columns:
  data_float[col] = data_float[col].fillna(data_float[col].mean())

# %%
data_float.isnull().sum()
# Out:
# Item_Weight          0
# Item_Visibility      0
# Item_Outlet_Sales    0
# Profit               0
# dtype: int64

# %%
data_int.isnull().sum()
# Out:
# Item_MRP                     0
# Outlet_Establishment_Year    0
# dtype: int64

# %%
data_object.isnull().sum()
# Out:
# Item_Identifier            0
# Item_Fat_Content           0
# Item_Type                  0
# Outlet_Identifier          0
# Outlet_Size             2410
# Outlet_Location_Type    2050
# Outlet_Type                0
# dtype: int64

# %%
sns.heatmap(data_object.isnull(), cbar=True)
# Out:
# <Axes: >

# %%
data["Outlet_Size"].value_counts()
# Out:
# Outlet_Size
# Medium    2793
# Small     2388
# High       932
# Name: count, dtype: int64

# %%
d = data["Outlet_Location_Type"].value_counts()

# %%
d.idxmax()
# Out:
# 'Tier 2'

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
for col in data_object:
  data_object[col] = data_object[col].fillna(data_object[col].value_counts().idxmax())

# %%
data_object.isnull().sum()
# Out:
# Item_Identifier         0
# Item_Fat_Content        0
# Item_Type               0
# Outlet_Identifier       0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# dtype: int64

# %%
data_object['Outlet_Size'].mode()
# Out:
# 0    Medium
# Name: Outlet_Size, dtype: object

# %%
data_object["Outlet_Location_Type"].mode()
# Out:
# 0    Tier 2
# Name: Outlet_Location_Type, dtype: object

# %%
for i in data_object.columns:
  print(i)
# Out:
# Item_Identifier
# Item_Fat_Content
# Item_Type
# Outlet_Identifier
# Outlet_Size
# Outlet_Location_Type
# Outlet_Type

# %%
# Another solution to fill null categories

for col in data_object.columns:
  mode = data_object[col].mode()[0]
  data_object[col] = data_object[col].fillna(mode)

# %%
data_object.isnull().sum()
# Out:
# Item_Identifier         0
# Item_Fat_Content        0
# Item_Type               0
# Outlet_Identifier       0
# Outlet_Size             0
# Outlet_Location_Type    0
# Outlet_Type             0
# dtype: int64

# %%
data_object.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
data_object['Outlet_Location_Type'].value_counts().index
# Out:
# Index(['Tier 2', 'Tier1', 'Tier 3', '?', '  --', '  -', 'na', 'NAN'], dtype='object', name='Outlet_Location_Type')

# %%
for character in ['?', '  --', '  -', 'na', 'NAN']:
  mode = data_object["Outlet_Location_Type"].mode()[0]
  data_object["Outlet_Location_Type"] = data_object["Outlet_Location_Type"].replace(character, mode)

# %%
data_object["Outlet_Location_Type"].mode()[0]
# Out:
# 'Tier 2'

# %%
data_object['Outlet_Location_Type'].value_counts()
# Out:
# Outlet_Location_Type
# Tier 2    5203
# Tier1     2388
# Tier 3     932
# Name: count, dtype: int64

# %% [markdown]
# # Scalling Data

# %%
data_float
# Out:
#       Item_Weight  Item_Visibility  Item_Outlet_Sales  Profit
# 0           9.300         0.016047          3735.1380    11.5
# 1           5.920         0.019278           443.4228    14.3
# 2          17.500         0.016760          2097.2700    14.5
# 3          19.200         0.000000           732.3800    13.6
# 4           8.930         0.000000           994.7052    14.1
# ...           ...              ...                ...     ...
# 8518        6.865         0.056783          2778.3834    14.1
# 8519        8.380         0.046982           549.2850    14.2
# 8520       10.600         0.035186          1193.1136     9.5
# 8521        7.210         0.145221          1845.5976    14.2
# 8522       14.800         0.044878           765.6700    14.6
#
# [8523 rows x 4 columns]

# %%
# Standard , min and max scaller

# %%
# mean of 1, 2, 4, 5 equals to 1+2+3+4 = 10 / 4 = 2.5
#(1-2.5)^2 + (2-2.5) ^ 2..../3 = 5/3 = 1.67 (variance)
# Standard deviation = math.sqrt(1.67)

'''
1 -> (1 - 2.5) / sqrt(1.67)
2 -> (2 - 2.5) / sqrt(1.67)
3 -> (3 - 2.5) / sqrt(1.67)
4 -> (4 - 2.5) / sqrt(1.67)
'''
# Out:
# '\n1 -> (1 - 2.5) / sqrt(1.67)\n2 -> (2 - 2.5) / sqrt(1.67)\n3 -> (3 - 2.5) / sqrt(1.67)\n4 -> (4 - 2.5) / sqrt(1.67)\n'

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
data.drop_duplicates(inplace=True)

# %%
scaler = StandardScaler()
array = scaler.fit_transform(data_float)

data_float_scalled = pd.DataFrame(array, columns = data_float.columns)

# %%
data_float_scalled
# Out:
#       Item_Weight  Item_Visibility  Item_Outlet_Sales    Profit
# 0       -0.430817        -0.970732           0.910601 -1.125033
# 1       -1.043488        -0.908111          -1.018440  0.520342
# 2        1.055545        -0.956917          -0.049238  0.637869
# 3        1.363694        -1.281758          -0.849103  0.108998
# 4       -0.497884        -1.281758          -0.695373  0.402815
# ...           ...              ...                ...       ...
# 8518    -0.872194        -0.181193           0.349915  0.402815
# 8519    -0.597579        -0.371154          -0.956402  0.461578
# 8520    -0.195174        -0.599784          -0.579100 -2.300301
# 8521    -0.809658         1.532880          -0.196725  0.461578
# 8522     0.566134        -0.411936          -0.829594  0.696632
#
# [8523 rows x 4 columns]

# %%
sns.displot(data_float_scalled["Profit"])

# %%
array = scaler.fit_transform(data_int)
data_int_scalled = pd.DataFrame(array, columns = data_int.columns)

# %%
data_int_scalled
# Out:
#       Item_MRP  Outlet_Establishment_Year
# 0     1.750116                   0.139541
# 1    -1.494573                   1.334103
# 2     0.015332                   0.139541
# 3     0.657844                   0.020085
# 4    -1.398196                  -1.293934
# ...        ...                        ...
# 8518  1.187917                  -1.293934
# 8519 -0.530804                   0.497909
# 8520 -0.900249                   0.736822
# 8521 -0.611118                   1.334103
# 8522 -1.044814                  -0.099372
#
# [8523 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.hist(data_float_scalled["Profit"], bins=5 )
# Out:
# (array([7.000e+01, 2.290e+02, 6.699e+03, 1.521e+03, 4.000e+00]),
#  array([-7.82405922, -5.01516931, -2.2062794 ,  0.6026105 ,  3.41150041,
#          6.22039032]),
#  <BarContainer object of 5 artists>)

# %%
# (x -> x - min)/max - mmin = 1

# %%
scaler = MinMaxScaler()
array = scaler.fit_transform(data_float)
data_float_scaled = pd.DataFrame(array, columns=data_float.columns)

# %%
# SNS 
# plt.boxplot(data_float_scalled)
sns.boxplot(data_float_scaled)
# Out:
# <Axes: >

# %%
def refill(number, upper_limit, lower_limit):

  if number > upper_limit:
    return upper_limit
  elif number < lower_limit:
    return lower_limit
  else:
    return number

for col in data_float_scaled.columns:
  q1 = np.quantile(data_float_scaled[col], 0.25) # first quantile
  q3 = np.quantile(data_float_scaled[col], 0.75)

  iqr = q3 - q1

  upper_limit = q3+1.5*iqr
  lower_limit = q1-1.5*iqr

  data_float_scaled[col] = data_float_scaled[col].apply(lambda x: refill(x, upper_limit, lower_limit))

# %%
print(q1, q3, iqr)
# Out:
# 0.5460251046025105 0.594142259414226 0.04811715481171552

# %%
sns.boxplot(data_float_scaled)
# Out:
# <Axes: >

# %%
data_int.std()
# Out:
# Item_MRP                     62.259243
# Outlet_Establishment_Year     8.371760
# dtype: float64

# %%
data_int.mean()
# Out:
# Item_MRP                      141.045524
# Outlet_Establishment_Year    1997.831867
# dtype: float64

# %%
## ??MinMaxScaller

??MinMaxScaler
# Out:
# Init signature: MinMaxScaler(feature_range=(0, 1), *, copy=True, clip=False)
# Source:
# class MinMaxScaler(OneToOneFeatureMixin, TransformerMixin, BaseEstimator):
#     """Transform features by scaling each feature to a given range.
#
#     This estimator scales and translates each feature individually such
#     that it is in the given range on the training set, e.g. between
#     zero and one.
#
#     The transformation is given by::
#
#         X_std = (X - X.min(axis=0)) / (X.max(axis=0) - X.min(axis=0))
#         X_scaled = X_std * (max - min) + min
#
#     where min, max = feature_range.
#
#     This transformation is often used as an alternative to zero mean,
#     unit variance scaling.
#
#     `MinMaxScaler` doesn't reduce the effect of outliers, but it linearly
#     scales them down into a fixed range, where the largest occurring data point
#     corresponds to the maximum value and the smallest one corresponds to the
# ...

# %%
# Duplicate data

data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales, Profit]
# Index: []

# %%
data_int[data_int.duplicated()]
# Out:
#       Item_MRP  Outlet_Establishment_Year
# 23         108                       1985
# 50         144                       1997
# 72         165                       2002
# 88          96                       1997
# 103         39                       1987
# ...        ...                        ...
# 8518       215                       1987
# 8519       108                       2002
# 8520        85                       2004
# 8521       103                       2009
# 8522        76                       1997
#
# [6604 rows x 2 columns]

# %%
data.drop_duplicates(inplace=True)

# %%
# data.to_csv("bigmartsales-cleaned.csv", index=False)

# %% [markdown]
# # Treatment of object/categorical data

# %%
# convert them to numerical data

data_object
# Out:
#      Item_Identifier Item_Fat_Content              Item_Type  \
# 0              FDA15          Low Fat                  Dairy
# 1              DRC01          Regular            Soft Drinks
# 2              FDN15          Low Fat                   Meat
# 3              FDX07          Regular  Fruits and Vegetables
# 4              NCD19          Low Fat              Household
# ...              ...              ...                    ...
# 8518           FDF22          Low Fat            Snack Foods
# 8519           FDS36          Regular           Baking Goods
# 8520           NCJ29          Low Fat     Health and Hygiene
# 8521           FDN46          Regular            Snack Foods
# 8522           DRG01          Low Fat            Soft Drinks
#
#      Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0               OUT049      Medium               Tier 2  Supermarket Type1
# 1               OUT018      Medium               Tier 2  Supermarket Type2
# ...

# %%
# Label encoder
# onehot encodign
# ordinal encoder

# %%
data_object["Item_Fat_Content"].unique()
# Out:
# array(['Low Fat', 'Regular'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder, OneHotEncoder

# %%
encoder = LabelEncoder()
# encoder.fit_transform(data_object["Item_Fat_Content"])
# encoder.inverse_transform([0,1])

# %%
data_object.head(4)
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 2  Supermarket Type1
# 1      Medium               Tier 2  Supermarket Type2
# 2      Medium               Tier 2  Supermarket Type1
# 3      Medium               Tier 2      Grocery Store

# %%
encoder = LabelEncoder()
data_object["Item_Identifier"] = encoder.fit_transform(data_object["Item_Identifier"])
data_object["Outlet_Identifier"] = encoder.fit_transform(data_object["Outlet_Identifier"])

# %%
data_object
# Out:
#       Item_Identifier Item_Fat_Content              Item_Type  \
# 0                 156          Low Fat                  Dairy
# 1                   8          Regular            Soft Drinks
# 2                 662          Low Fat                   Meat
# 3                1121          Regular  Fruits and Vegetables
# 4                1297          Low Fat              Household
# ...               ...              ...                    ...
# 8518              370          Low Fat            Snack Foods
# 8519              897          Regular           Baking Goods
# 8520             1357          Low Fat     Health and Hygiene
# 8521              681          Regular            Snack Foods
# 8522               50          Low Fat            Soft Drinks
#
#       Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# 0                     9      Medium               Tier 2  Supermarket Type1
# ...

# %%
for col in data_object.columns:
  (data_object[col].unique())

# %%
encoder = OrdinalEncoder(categories=[["Low Fat", "Regular"]])
data_object["Item_Fat_Content"]=encoder.fit_transform(data_object[["Item_Fat_Content"]])

encoder = OrdinalEncoder(categories=[["Small", "Medium", "High"]])
data_object["Outlet_Size"]=encoder.fit_transform(data_object[["Outlet_Size"]])


encoder = OrdinalEncoder(categories=[["Tier 3", "Tier 2", "Tier1"]])
data_object["Outlet_Location_Type"]=encoder.fit_transform(data_object[["Outlet_Location_Type"]])

# %%
data_object["Outlet_Location_Type"].unique()
# Out:
# array([1., 0., 2.])

# %%
one_hot_encoding = pd.get_dummies(data_object[["Item_Type", "Outlet_Type"]]).astype("int")

# %%
# one_hot_encoding = pd.get_

# %%
# data_int_scaled, data_float_scaled, data_object, one_hot_encoding

# %%
data_object.drop(["Item_Type", "Outlet_Type"], axis=1, inplace=True)

# %%
df_final = pd.concat([data_int_scalled, data_float_scalled, data_object, one_hot_encoding], axis=1)

# %%
df_final
# Out:
#       Item_MRP  Outlet_Establishment_Year  Item_Weight  Item_Visibility  \
# 0     1.750116                   0.139541    -0.430817        -0.970732
# 1    -1.494573                   1.334103    -1.043488        -0.908111
# 2     0.015332                   0.139541     1.055545        -0.956917
# 3     0.657844                   0.020085     1.363694        -1.281758
# 4    -1.398196                  -1.293934    -0.497884        -1.281758
# ...        ...                        ...          ...              ...
# 8518  1.187917                  -1.293934    -0.872194        -0.181193
# 8519 -0.530804                   0.497909    -0.597579        -0.371154
# 8520 -0.900249                   0.736822    -0.195174        -0.599784
# 8521 -0.611118                   1.334103    -0.809658         1.532880
# 8522 -1.044814                  -0.099372     0.566134        -0.411936
#
#       Item_Outlet_Sales    Profit  Item_Identifier  Item_Fat_Content  \
# ...

# %%
data_object.columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type'],
#       dtype='object')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
data_ml = pd.DataFrame()
data_ml["x"] = [1, 2, 3, 4]
data_ml['y'] = [9, 10, 16, 25]

data_ml
# Out:
#    x   y
# 0  1   9
# 1  2  10
# 2  3  16
# 3  4  25

# %%
model = LinearRegression()
model.fit(data_ml[["x"]], data_ml["y"])
# Out:
# LinearRegression()

# %%
data_ml["x"]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: x, dtype: int64

# %%
data_ml["y"]
# Out:
# 0     9
# 1    10
# 2    16
# 3    25
# Name: y, dtype: int64

# %%
model.coef_, model.intercept_
# Out:
# (array([5.4]), 1.5000000000000036)

# %%
pred = model.predict(data_ml[["x"]])
r2_score(data_ml["y"], pred)
# Out:
# 0.9

# %%
pred
# Out:
# array([ 6.9, 12.3, 17.7, 23.1])
